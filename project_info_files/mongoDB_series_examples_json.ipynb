# %%
# comany data structure
myJSON = {"_id":{"$oid":"628ea00f5a3e60ccebaa0fec"},
          "LogDateTime":{"$date":"2022-03-04T12:30:00.000Z"},
          "MBusPowerMeter_KWhConsumedInterval_Sum":0.03000000000000025,
        #   "InterPredicted":false
          }

# %%
# Loop 20 times to generate hourly timestamps
for i in range(20):
    # Add one hour to the starting datetime for each iteration
    hourly_data.append(start_dt + timedelta(hours=i))

print(hourly_data)

myDT = [
    datetime(2024, 6, 15, 0, 0),
    datetime(2024, 6, 15, 1, 0),
    datetime(2024, 6, 15, 2, 0),
    datetime(2024, 6, 15, 3, 0),
    datetime(2024, 6, 15, 4, 0),
    datetime(2024, 6, 15, 5, 0),
    datetime(2024, 6, 15, 6, 0),
    datetime(2024, 6, 15, 7, 0),
    datetime(2024, 6, 15, 8, 0),
    datetime(2024, 6, 15, 9, 0),
    datetime(2024, 6, 15, 10, 0),
    datetime(2024, 6, 15, 11, 0),
    datetime(2024, 6, 15, 12, 0),
    datetime(2024, 6, 15, 13, 0),
    datetime(2024, 6, 15, 14, 0),
    datetime(2024, 6, 15, 15, 0),
    datetime(2024, 6, 15, 16, 0),
    datetime(2024, 6, 15, 17, 0),
    datetime(2024, 6, 15, 18, 0),
    datetime(2024, 6, 15, 19, 0),
]

# %%
myDT = [
    "2024-06-04 08:00:00",
    "2024-06-04 09:00:00",
    "2024-06-04 10:00:00",
    "2024-06-04 11:00:00",
    "2024-06-04 12:00:00",
    "2024-06-04 13:00:00",
    "2024-06-04 14:00:40",
    "2024-06-04 15:00:00",
    "2024-06-04 16:00:00",
    "2024-06-04 17:00:00",
    "2024-06-04 18:00:00",
    "2024-06-04 19:00:00",
    "2024-06-04 20:00:00",
    "2024-06-04 21:00:00",
    "2024-06-04 22:00:00",
    "2024-06-04 23:00:00",
    "2024-06-05 00:00:00",
    "2024-06-05 01:00:00",
    "2024-06-05 02:00:00",
]

# %%
myDT = [
    "2024-06-04 08:00:00", 
    "2024-06-04 09:00:00",
    "2024-06-04 10:00:00",
    "2024-06-04 11:00:00",
    "2024-06-04 12:00:00",
    "2024-06-04 13:00:00",
    "2024-06-04 14:00:40",
    "2024-06-04 15:00:00",
    "2024-06-04 16:00:00",
    "2024-06-04 17:00:00",
    "2024-06-04 18:00:00",
    "2024-06-04 19:00:00",
    "2024-06-04 20:00:00",
    "2024-06-04 21:00:00",
    "2024-06-04 22:00:00",
    "2024-06-04 23:00:00",
    "2024-06-05 00:00:00",
    "2024-06-05 01:00:00",
    "2024-06-05 02:00:00",
]

# %%
series_dicts = [
    {
        "DateTime": "2024-06-18T12:00:00.000Z",  # String format
        "Actual": 48,
        "Forecast": 95
    },
    {
        "DateTime": "2024-06-18T12:15:00.000Z",
        "Actual": 52,
        "Forecast": 98
    },
    {
        "DateTime": "2024-06-18T12:30:00.000Z",
        "Actual": 55,
        "Forecast": 100
    },
    {
        "DateTime": "2024-06-18T12:45:27.174Z",  # Your existing entry
        "Actual": 55,
        "Forecast": 99
    },
    {
        "DateTime": "2024-06-18T13:00:00.000Z",  # Your existing entry
        "Actual": 62,
        "Forecast": 105
    },
    {
        "DateTime": "2024-06-18T13:15:00.000Z",
        "Actual": 60,
        "Forecast": 102
    },
    {
        "DateTime": "2024-06-18T13:30:00.000Z",
        "Actual": 58,
        "Forecast": 100
    },
    {
        "DateTime": "2024-06-18T13:45:00.000Z",
        "Actual": 61,
        "Forecast": 103
    },
    {
        "DateTime": "2024-06-18T14:00:00.000Z",
        "Actual": 59,
        "Forecast": 101
    },
    {
        "DateTime": "2024-06-18T14:15:00.000Z",
        "Actual": 63,
        "Forecast": 104
    },
    {
        "DateTime": "2024-06-18T14:30:00.000Z",
        "Actual": 60,
        "Forecast": 102
    },
    {
        "DateTime": "2024-06-18T14:45:00.000Z",
        "Actual": 57,
        "Forecast": 99
    },
    {
        "DateTime": "2024-06-18T15:00:00.000Z",
        "Actual": 64,
        "Forecast": 106
    },
    {
        "DateTime": "2024-06-18T15:15:00.000Z",
        "Actual": 62,
        "Forecast": 103
    },
    {
        "DateTime": "2024-06-18T15:30:00.000Z",
        "Actual": 59,
        "Forecast": 101
    },
    {
        "DateTime": "2024-06-18T15:45:00.000Z",
        "Actual": 66,
        "Forecast": 108
    },
    {
        "DateTime": "2024-06-18T16:00:00.000Z",
        "Actual": 61,
        "Forecast": 102
    },
    {
        "DateTime": "2024-06-18T16:15:00.000Z",
        "Actual": 58,
        "Forecast": 1

# %%
from datetime import datetime

series_dicts = 
[
    {
        "DateTime": datetime.fromisoformat("2024-06-18T12:00:00.000Z"),
        "Actual": 48,
        "Forecast": 95
    },
    {
        "DateTime": datetime.fromisoformat("2024-06-18T12:15:00.000Z"),
        "Actual": 52,
        "Forecast": 98
    },
    {
        "DateTime": datetime.fromisoformat("2024-06-18T12:30:00.000Z"),
        "Actual": 55,
        "Forecast": 100
    },
    {
        "DateTime": datetime.fromisoformat("2024-06-18T12:45:27.174Z"),
        "Actual": 55,
        "Forecast": 99
    },
    {
        "DateTime": datetime.fromisoformat("2024-06-18T13:00:00.000Z"),
        "Actual": 62,
        "Forecast": 105
    },
    {
        "DateTime": datetime.fromisoformat("2024-06-18T13:15:00.000Z"),
        "Actual": 60,
        "Forecast": 102
    },
    {
        "DateTime": datetime.fromisoformat("2024-06-18T13:30:00.000Z"),
        "Actual": 58,
        "Forecast": 100
    },
    {
        "DateTime": datetime.fromisoformat("2024-06-18T13:45:00.000Z"),
        "Actual": 61,
        "Forecast": 103
    },
    {
        "DateTime": datetime.fromisoformat("2024-06-18T14:00:00.000Z"),
        "Actual": 59,
        "Forecast": 101
    },
    {
        "DateTime": datetime.fromisoformat("2024-06-18T14:15:00.000Z"),
        "Actual": 63,
        "Forecast": 104
    },
    {
        "DateTime": datetime.fromisoformat("2024-06-18T14:30:00.000Z"),
        "Actual": 60,
        "Forecast": 102
    },
    {
        "DateTime": datetime.fromisoformat("2024-06-18T14:45:00.000Z"),
        "Actual": 57,
        "Forecast": 99
    },
    {
        "DateTime": datetime.fromisoformat("2024-06-18T15:00:00.000Z"),
        "Actual": 64,
        "Forecast": 106
    },
    {
        "DateTime": datetime.fromisoformat("2024-06-18T15:15:00.000Z"),
        "Actual": 62,
        "Forecast": 103
    },
    {
        "DateTime": datetime.fromisoformat("2024-06-18T15:30:00.000Z"),
        "Actual": 59,
        "Forecast": 101
    },
    {
        "DateTime": datetime.fromisoformat("2024-06-18T15:45:00.000Z"),
        "Actual": 66,
        "Forecast": 108
    }
]

# %%
[
    {
        "DateTime": "2024-06-18T12:00:00.000Z",
        "Actual": 48,
        "Forecast": 95
    },
    {
        "DateTime": "2024-06-18T12:15:00.000Z",
        "Actual": 52,
        "Forecast": 98
    },
    {
        "DateTime": "2024-06-18T12:30:00.000Z",
        "Actual": 55,
        "Forecast": 100
    },
    {
        "DateTime": "2024-06-18T12:45:27.174Z",
        "Actual": 55,
        "Forecast": 99
    },
    {
        "DateTime": "2024-06-18T13:00:00.000Z",
        "Actual": 62,
        "Forecast": 105
    },
    {
        "DateTime": "2024-06-18T13:15:00.000Z",
        "Actual": 60,
        "Forecast": 102
    },
    {
        "DateTime": "2024-06-18T13:30:00.000Z",
        "Actual": 58,
        "Forecast": 100
    },
    {
        "DateTime": "2024-06-18T13:45:00.000Z",
        "Actual": 61,
        "Forecast": 103
    },
    {
        "DateTime": "2024-06-18T14:00:00.000Z",
        "Actual": 59,
        "Forecast": 101
    },
    {
        "DateTime": "2024-06-18T14:15:00.000Z",
        "Actual": 63,
        "Forecast": 104
    },
    {
        "DateTime": "2024-06-18T14:30:00.000Z",
        "Actual": 60,
        "Forecast": 102
    },
    {
        "DateTime": "2024-06-18T14:45:00.000Z",
        "Actual": 57,
        "Forecast": 99
    },
    {
        "DateTime": "2024-06-18T15:00:00.000Z",
        "Actual": 64,
        "Forecast": 106
    },
    {
        "DateTime": "2024-06-18T15:15:00.000Z",
        "Actual": 62,
        "Forecast": 103
    },
    {
        "DateTime": "2024-06-18T15:30:00.000Z",
        "Actual": 59,
        "Forecast": 101
    },
    {
        "DateTime": "2024-06-18T15:45:00.000Z",
        "Actual": 66,
        "Forecast": 108
    }
]

# %%
series_dicts = [
    {
        "DateTime": datetime.strptime("2024-01-01 10:00:00", "%Y-%m-%d %H:%M:%S"),
        "Actual": 48,
        "Forecast": 95
    },
    {
        "DateTime": datetime.strptime("2024-01-01 10:15:00", "%Y-%m-%d %H:%M:%S"),
        "Actual": 52,
        "Forecast": 98
    },
    {
        "DateTime": datetime.strptime("2024-01-01 15:45:00", "%Y-%m-%d %H:%M:%S"),
        "Actual": 66,
        "Forecast": 108
    },
]

# %%
[
{
    "DateTime": "2024-01-01 10:00:00",
    "Actual": 48,
    "Forecast": 95
},
{
    "DateTime": "2024-01-01 10:15:00",
    "Actual": 52,
    "Forecast": 98
},
{
    "DateTime": "2024-01-01 15:45:00",
    "Actual": 66,
    "Forecast": 108
}
]

# %%
[
  {
    "DateTime": "2024-06-19T18:12:39.970Z",
    "Actual": 999,
    "Forecast": 999
  },
 {  
   "DateTime": "2024-07-19T18:12:39.970Z",
   "Actual": 555,
   "Forecast": 555
 }
]
